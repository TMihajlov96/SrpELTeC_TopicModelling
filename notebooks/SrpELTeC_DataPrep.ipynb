# %%
import spacy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import spacy
#
# File ~/Projects/CLIB_TopicVisualization/.venv/lib/python3.11/site-packages/spacy/__init__.py:6
#       3 from typing import Any, Dict, Iterable, Union
#       5 # set library-specific custom warning handling before doing anything else
# ----> 6 from .errors import setup_default_warnings
#       8 setup_default_warnings()  # noqa: E402
#      10 # These are imported as part of the API
#
# File ~/Projects/CLIB_TopicVisualization/.venv/lib/python3.11/site-packages/spacy/errors.py:3
#       1 import warnings
# ----> 3 from .compat import Literal
#       6 class ErrorsWithCodes(type):
#       7     def __getattribute__(self, code):
#
# File ~/Projects/CLIB_TopicVisualization/.venv/lib/python3.11/site-packages/spacy/compat.py:39
#      36 except ImportError:
# ...
